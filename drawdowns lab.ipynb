# %%
import pandas as pd
# %matplotlib inline
me_m = pd.read_csv("C:/Users/anasf/Desktop/EDHEC Portfolio Management Specialization/data/Portfolios_Formed_on_ME_monthly_EW.csv",
                  header=0, index_col=0, parse_dates=True, na_values=-99.99
                  )
rets = me_m[['Lo 10','Hi 10']]
rets.columns = ['Small Cap', 'Large Cap']
rets = rets/100
rets.plot.line()

# %%
rets.index = pd.to_datetime(rets.index, format="%Y%m")
rets.index = rets.index.to_period("M")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-2a24a5c95624> in <module>
# ----> 1 rets.index = pd.to_datetime(rets.index, format="%Y%m")
#       2 rets.index = rets.index.to_period("M")
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     736         else:
#     737             convert_listlike = partial(convert_listlike, name=arg.name)
# --> 738             result = convert_listlike(arg, format)
#     739     elif is_list_like(arg):
#     740         try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     361     # NB: this must come after unit transformation
#     362     orig_arg = arg
# --> 363     arg, _ = maybe_convert_dtype(arg, copy=False)
#     364
#     365     arg = ensure_object(arg)
#
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in maybe_convert_dtype(data, copy)
#    1919         #  test_setops.test_join_does_not_recur fails
#    1920         raise TypeError(
# -> 1921             "Passing PeriodDtype data is invalid. Use `data.to_timestamp()` instead"
#    1922         )
#    1923
#
# TypeError: Passing PeriodDtype data is invalid. Use `data.to_timestamp()` instead

# %%
wealth_index = 100*(1 + rets["Large Cap"]).cumprod()
wealth_index.plot.line()

# %%
previous_peaks = wealth_index.cummax()
previous_peaks.plot.line()

# %%
drawdown = (wealth_index - previous_peaks) / previous_peaks
drawdown.plot.line()

# %%
drawdown["1975":].idxmin()
# Out:
# Period('2009-02', 'M')

# %%
drawdown.idxmin()
# Out:
# Period('1932-05', 'M')
